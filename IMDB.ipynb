# %%
# import major libraries

import pandas as pd
import numpy as np

# %%
df = pd.read_csv('movies.csv')
df
# Out:
#                                    title_x     imdb_id  \
# 0                 Uri: The Surgical Strike   tt8291224
# 1                            Battalion 609   tt9472208
# 2     The Accidental Prime Minister (film)   tt6986710
# 3                          Why Cheat India   tt8108208
# 4                          Evening Shadows   tt6028796
# ...                                    ...         ...
# 1624                 Tera Mera Saath Rahen   tt0301250
# 1625                  Yeh Zindagi Ka Safar   tt0298607
# 1626                       Sabse Bada Sukh   tt0069204
# 1627                                 Daaka  tt10833860
# 1628                              Humsafar   tt2403201
#
#                                             poster_path  \
# 0     https://upload.wikimedia.org/wikipedia/en/thum...
# 1                                                   NaN
# 2     https://upload.wikimedia.org/wikipedia/en/thum...
# 3     https://upload.wikimedia.org/wikipedia/en/thum...
# ...

# %%
# shape

df.shape
# Out:
# (1629, 18)

# %% [markdown]
# Dataset consists of 1629 rows and 18 columns

# %%
# index

df.index
# Out:
# RangeIndex(start=0, stop=1629, step=1)

# %%
# values --> converts dataframe to array

df.values[0]
# Out:
# array(['Uri: The Surgical Strike', 'tt8291224',
#        'https://upload.wikimedia.org/wikipedia/en/thumb/3/3b/URI_-_New_poster.jpg/220px-URI_-_New_poster.jpg',
#        'https://en.wikipedia.org/wiki/Uri:_The_Surgical_Strike',
#        'Uri: The Surgical Strike', 'Uri: The Surgical Strike', 0, 2019,
#        '138', 'Action|Drama|War', 8.4, 35112,
#        'Divided over five chapters  the film chronicles the events of the surgical strike conducted by the Indian military against suspected militants in Pakistan occupied Kashmir. It tells the story of the 11 tumultuous events over which the operation was carried out. Indian army special forces carry out a covert operation to avenge the killing of fellow army men at their base by a terrorist group.',
#        'Indian army special forces execute a covert operation  avenging the killing of fellow army men at their base by a terrorist group.',
#        nan,
# ...

# %%
# dtypes

df.dtypes
# Out:
# title_x              object
# imdb_id              object
# poster_path          object
# wiki_link            object
# title_y              object
# original_title       object
# is_adult              int64
# year_of_release       int64
# runtime              object
# genres               object
# imdb_rating         float64
# imdb_votes            int64
# story                object
# summary              object
# tagline              object
# actors               object
# wins_nominations     object
# release_date         object
# dtype: object

# %%
# overview

df.head()
# Out:
#                                 title_x    imdb_id  \
# 0              Uri: The Surgical Strike  tt8291224
# 1                         Battalion 609  tt9472208
# 2  The Accidental Prime Minister (film)  tt6986710
# 3                       Why Cheat India  tt8108208
# 4                       Evening Shadows  tt6028796
#
#                                          poster_path  \
# 0  https://upload.wikimedia.org/wikipedia/en/thum...
# 1                                                NaN
# 2  https://upload.wikimedia.org/wikipedia/en/thum...
# 3  https://upload.wikimedia.org/wikipedia/en/thum...
# 4                                                NaN
#
#                                            wiki_link  \
# 0  https://en.wikipedia.org/wiki/Uri:_The_Surgica...
# 1        https://en.wikipedia.org/wiki/Battalion_609
# 2  https://en.wikipedia.org/wiki/The_Accidental_P...
# 3      https://en.wikipedia.org/wiki/Why_Cheat_India
# 4      https://en.wikipedia.org/wiki/Evening_Shadows
#
# ...

# %%
df.sample(5)
# Out:
#                      title_x    imdb_id  \
# 911           Action Replayy  tt1396208
# 178         Phillauri (film)  tt5502766
# 887       Ramayana: The Epic  tt1744641
# 1407                   Aanch  tt0389726
# 190   Half Girlfriend (film)  tt5474042
#
#                                             poster_path  \
# 911   https://upload.wikimedia.org/wikipedia/en/thum...
# 178   https://upload.wikimedia.org/wikipedia/en/thum...
# 887   https://upload.wikimedia.org/wikipedia/en/a/ac...
# 1407  https://upload.wikimedia.org/wikipedia/en/thum...
# 190   https://upload.wikimedia.org/wikipedia/en/thum...
#
#                                               wiki_link             title_y  \
# 911        https://en.wikipedia.org/wiki/Action_Replayy       Action Replay
# 178      https://en.wikipedia.org/wiki/Phillauri_(film)           Phillauri
# 887    https://en.wikipedia.org/wiki/Ramayana:_The_Epic  Ramayana: The Epic
# ...

# %%
#info
#seeking information of dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1629 entries, 0 to 1628
# Data columns (total 18 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   title_x           1629 non-null   object
#  1   imdb_id           1629 non-null   object
#  2   poster_path       1526 non-null   object
#  3   wiki_link         1629 non-null   object
#  4   title_y           1629 non-null   object
#  5   original_title    1629 non-null   object
#  6   is_adult          1629 non-null   int64
#  7   year_of_release   1629 non-null   int64
#  8   runtime           1629 non-null   object
#  9   genres            1629 non-null   object
#  10  imdb_rating       1629 non-null   float64
#  11  imdb_votes        1629 non-null   int64
#  12  story             1609 non-null   object
#  13  summary           1629 non-null   object
#  14  tagline           557 non-null    object
#  15  actors            1624 non-null   object
# ...

# %%
#describe
#seeking desciption of dataset
df.describe()
# Out:
#        is_adult  year_of_release  imdb_rating     imdb_votes
# count    1629.0      1629.000000  1629.000000    1629.000000
# mean        0.0      2010.263966     5.557459    5384.263352
# std         0.0         5.381542     1.567609   14552.103231
# min         0.0      2001.000000     0.000000       0.000000
# 25%         0.0      2005.000000     4.400000     233.000000
# 50%         0.0      2011.000000     5.600000    1000.000000
# 75%         0.0      2015.000000     6.800000    4287.000000
# max         0.0      2019.000000     9.400000  310481.000000

# %%
#columns
df.columns
# Out:
# Index(['title_x', 'imdb_id', 'poster_path', 'wiki_link', 'title_y',
#        'original_title', 'is_adult', 'year_of_release', 'runtime', 'genres',
#        'imdb_rating', 'imdb_votes', 'story', 'summary', 'tagline', 'actors',
#        'wins_nominations', 'release_date'],
#       dtype='object')

# %%
#numerical columns
num=list(df.describe().columns)
#categorical
cat=[]
for i in df.columns:
    if i not in num:
        cat.append(i)
print('numerical columns\t',num)
print('categorical columns\t',cat)
# Out:
# numerical columns	 ['is_adult', 'year_of_release', 'imdb_rating', 'imdb_votes']
# categorical columns	 ['title_x', 'imdb_id', 'poster_path', 'wiki_link', 'title_y', 'original_title', 'runtime', 'genres', 'story', 'summary', 'tagline', 'actors', 'wins_nominations', 'release_date']

# %% [markdown]
# # selecting and indexing
# - df['col']
# - df.col
# - df.iloc
# - df.loc
# - df.query
# - fancy.indexing

# %%
df['imdb_votes']  #--->series #1d array
df.imdb_votes #---series__1d array
# Out:
# 0       35112
# 1          73
# 2        5549
# 3        1891
# 4         280
#         ...
# 1624      278
# 1625      133
# 1626       13
# 1627       38
# 1628     2968
# Name: imdb_votes, Length: 1629, dtype: int64

# %%
df[['imdb_votes']] #----data frame 2d array
# Out:
#       imdb_votes
# 0          35112
# 1             73
# 2           5549
# 3           1891
# 4            280
# ...          ...
# 1624         278
# 1625         133
# 1626          13
# 1627          38
# 1628        2968
#
# [1629 rows x 1 columns]

# %%
#multiple columns
#rating,votes
df[['imdb_rating','imdb_votes']].head()
# Out:
#    imdb_rating  imdb_votes
# 0          8.4       35112
# 1          4.1          73
# 2          6.1        5549
# 3          6.0        1891
# 4          7.3         280

# %%
#graphs
import seaborn as sns 
import matplotlib.pyplot as plt
plt.figure(figsize=(12,4))
sns.kdeplot(df[['imdb_votes']])
plt.title('distribution of imdb votes')
plt.show()
plt.figure(figsize=(12,4))
plt.boxplot(x=df['imdb_votes'])
plt.title('whisker plot of imdb votes')
plt.show()
#skew
df[['imdb_votes']].skew()
# Out:
# imdb_votes    9.090972
# dtype: float64

# %%
#iloc-->indexes
#loc--->labelled indexes
#row fetch
df.iloc[4:7]  #slicing
# Out:
#            title_x    imdb_id  \
# 4  Evening Shadows  tt6028796
# 5      Soni (film)  tt6078866
# 6    Fraud Saiyaan  tt5013008
#
#                                          poster_path  \
# 4                                                NaN
# 5  https://upload.wikimedia.org/wikipedia/en/thum...
# 6  https://upload.wikimedia.org/wikipedia/en/thum...
#
#                                        wiki_link          title_y  \
# 4  https://en.wikipedia.org/wiki/Evening_Shadows  Evening Shadows
# 5      https://en.wikipedia.org/wiki/Soni_(film)             Soni
# 6    https://en.wikipedia.org/wiki/Fraud_Saiyaan    Fraud Saiyaan
#
#     original_title  is_adult  year_of_release runtime        genres  \
# 4  Evening Shadows         0             2018     102         Drama
# 5             Soni         0             2018      97         Drama
# 6    Fraud Saiyyan         0             2019     109  Comedy|Drama
#
# ...

# %%
df.iloc[[10,20,30]]#fancy slicing
# Out:
#                       title_x    imdb_id  \
# 10                     Amavas  tt8396186
# 20  Mere Pyare Prime Minister  tt8207768
# 30      Student of the Year 2  tt7255568
#
#                                           poster_path  \
# 10  https://upload.wikimedia.org/wikipedia/en/thum...
# 20  https://upload.wikimedia.org/wikipedia/en/thum...
# 30  https://upload.wikimedia.org/wikipedia/en/thum...
#
#                                             wiki_link  \
# 10               https://en.wikipedia.org/wiki/Amavas
# 20  https://en.wikipedia.org/wiki/Mere_Pyare_Prime...
# 30  https://en.wikipedia.org/wiki/Student_of_the_Y...
#
#                       title_y             original_title  is_adult  \
# 10                     Amavas                     Amavas         0
# 20  Mere Pyare Prime Minister  Mere Pyare Prime Minister         0
# 30      Student of the Year 2      Student of the Year 2         0
#
#     year_of_release runtime               genres  imdb_rating  imdb_votes  \
# ...

# %%
df.iloc[:]
df.iloc[:,0:5]  #columns
df.iloc[:,5:10]  #columns
# Out:
#                      original_title  is_adult  year_of_release runtime  \
# 0          Uri: The Surgical Strike         0             2019     138
# 1                     Battalion 609         0             2019     131
# 2     The Accidental Prime Minister         0             2019     112
# 3                   Why Cheat India         0             2019     121
# 4                   Evening Shadows         0             2018     102
# ...                             ...       ...              ...     ...
# 1624          Tera Mera Saath Rahen         0             2001     148
# 1625           Yeh Zindagi Ka Safar         0             2001     146
# 1626                Sabse Bada Sukh         0             2018      \N
# 1627                          Daaka         0             2019     136
# 1628                       Humsafar         0             2011      35
#
#                 genres
# 0     Action|Drama|War
# 1                  War
# 2      Biography|Drama
# ...

# %%
#loc
#rows
df.loc[5:10]  #rows
df.columns
#filteration
df.loc[:,['imdb_id','original_title','story','summary']]
# Out:
#          imdb_id                 original_title  \
# 0      tt8291224       Uri: The Surgical Strike
# 1      tt9472208                  Battalion 609
# 2      tt6986710  The Accidental Prime Minister
# 3      tt8108208                Why Cheat India
# 4      tt6028796                Evening Shadows
# ...          ...                            ...
# 1624   tt0301250          Tera Mera Saath Rahen
# 1625   tt0298607           Yeh Zindagi Ka Safar
# 1626   tt0069204                Sabse Bada Sukh
# 1627  tt10833860                          Daaka
# 1628   tt2403201                       Humsafar
#
#                                                   story  \
# 0     Divided over five chapters  the film chronicle...
# 1     The story revolves around a cricket match betw...
# 2     Based on the memoir by Indian policy analyst S...
# 3     The movie focuses on existing malpractices in ...
# 4     While gay rights and marriage equality has bee...
# ...

# %% [markdown]
# # query
# df.query('imdb_rating>9')
#
# ## data cleaning veery important
# - isnull()
# - dropna()
# - drop
# - filna()
# - duplicated()
# - drop-dulpicated()
# - rename()
# - astype()

# %%
df.isnull().sum()
# Out:
# title_x                0
# imdb_id                0
# poster_path          103
# wiki_link              0
# title_y                0
# original_title         0
# is_adult               0
# year_of_release        0
# runtime                0
# genres                 0
# imdb_rating            0
# imdb_votes             0
# story                 20
# summary                0
# tagline             1072
# actors                 5
# wins_nominations     922
# release_date         107
# dtype: int64

# %%
#average
df.isnull().mean().round(4)*100
# Out:
# title_x              0.00
# imdb_id              0.00
# poster_path          6.32
# wiki_link            0.00
# title_y              0.00
# original_title       0.00
# is_adult             0.00
# year_of_release      0.00
# runtime              0.00
# genres               0.00
# imdb_rating          0.00
# imdb_votes           0.00
# story                1.23
# summary              0.00
# tagline             65.81
# actors               0.31
# wins_nominations    56.60
# release_date         6.57
# dtype: float64

# %%
#dropna
print('prior shape',df.shape)
df.dropna(subset=['actors','story'])  #temporary
df.dropna(subset=['actors','story'],inplace=True)  #permanent
df.shape
# Out:
# prior shape (1629, 18)
# (1607, 18)

# %%
#drop
print('prior shape')
print(df.shape)
df.drop(columns=['tagline','wins_nominations','is_adult','title_x','title_y','story']) # temporary
df.drop(columns=['tagline','wins_nominations','is_adult','title_x','title_y','story'],inplace=True) # permanent
print('shape after droping columns')
print(df.shape)
# Out:
# prior shape
# (1607, 18)
# shape after droping columns
# (1607, 12)

# %%
# filling null values
# PLACEHOLDER --> UNKNOWN
df.poster_path.fillna('unknown') #temporary change
df.poster_path.fillna('unknown',inplace=True) # permanent change
# Out:
# C:\Users\bhumika singhal\AppData\Local\Temp\ipykernel_39264\3015255457.py:4: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df.poster_path.fillna('unknown',inplace=True) # permanent change

# %%
df.release_date
df.isnull().mean()
df.release_date.mode().values
# Out:
# array(['14 October 2016 (India)', '18 July 2014 (India)',
#        '8 June 2007 (India)', '9 May 2014 (India)'], dtype=object)

# %%
df.release_date.fillna('14 October 2016 (INDIA)',inplace=True) # permanent change
# Out:
# C:\Users\bhumika singhal\AppData\Local\Temp\ipykernel_39264\2886678265.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df.release_date.fillna('14 October 2016 (INDIA)',inplace=True) # permanent change

# %%
print(df.isnull().sum().sum())
# Out:
# 0

# %% [raw]
# dataset is free from issues of completeness

# %%
# duplicates
# df.drop_duplicates()

# %%
# rename
# columns

df.rename({'imdb_id':'id','original_title':'title','year_of_release':'release_year'}
          ,axis=1,inplace=True) #permanent

df.head()
# Out:
#           id                                        poster_path  \
# 0  tt8291224  https://upload.wikimedia.org/wikipedia/en/thum...
# 1  tt9472208                                            unknown
# 2  tt6986710  https://upload.wikimedia.org/wikipedia/en/thum...
# 3  tt8108208  https://upload.wikimedia.org/wikipedia/en/thum...
# 4  tt6028796                                            unknown
#
#                                            wiki_link  \
# 0  https://en.wikipedia.org/wiki/Uri:_The_Surgica...
# 1        https://en.wikipedia.org/wiki/Battalion_609
# 2  https://en.wikipedia.org/wiki/The_Accidental_P...
# 3      https://en.wikipedia.org/wiki/Why_Cheat_India
# 4      https://en.wikipedia.org/wiki/Evening_Shadows
#
#                            title  release_year runtime            genres  \
# 0       Uri: The Surgical Strike          2019     138  Action|Drama|War
# 1                  Battalion 609          2019     131               War
# ...

# %%
# astype

# df.runtime.astype('int')
# invalid literal for int() with bas10: '\\N'

# %%
# str.attribute
# apply function

# %%
df[~df.runtime.str.isnumeric()] # total 109 rows
# Out:
#               id                                        poster_path  \
# 48     tt7228072  https://upload.wikimedia.org/wikipedia/en/thum...
# 60    tt11007050  https://upload.wikimedia.org/wikipedia/en/thum...
# 186    tt6752836  https://upload.wikimedia.org/wikipedia/en/thum...
# 245    tt7571718  https://upload.wikimedia.org/wikipedia/en/thum...
# 290    tt5456810                                            unknown
# ...          ...                                                ...
# 1604   tt0272735  https://upload.wikimedia.org/wikipedia/en/f/f8...
# 1606   tt0396044                                            unknown
# 1611   tt0285958  https://upload.wikimedia.org/wikipedia/en/thum...
# 1617   tt0265452                                            unknown
# 1626   tt0069204                                            unknown
#
#                                               wiki_link  \
# 48                https://en.wikipedia.org/wiki/Pranaam
# ...

# %%
# apply

df.runtime.apply(lambda x: np.nan if x =='\\N' else x)
# Out:
# 0       138
# 1       131
# 2       112
# 3       121
# 4       102
#        ...
# 1624    148
# 1625    146
# 1626    NaN
# 1627    136
# 1628     35
# Name: runtime, Length: 1607, dtype: object

# %%
# df.runtime.value_counts()
# permanent
df.runtime = df.runtime.apply(lambda x: np.nan if x =='\\N' else x)
df.isnull().sum()
# Out:
# id                0
# poster_path       0
# wiki_link         0
# title             0
# release_year      0
# runtime         109
# genres            0
# imdb_rating       0
# imdb_votes        0
# summary           0
# actors            0
# release_date      0
# dtype: int64

# %%
df.runtime.mode()
# Out:
# 0    120
# Name: runtime, dtype: object

# %%
# filling null values and changing data type
df.runtime = df.runtime.fillna('120').astype(int)

# %%
df.sample(3)
# Out:
#              id                                        poster_path  \
# 1391  tt0410954                                            unknown
# 1283  tt0435259  https://upload.wikimedia.org/wikipedia/en/thum...
# 1500  tt0326722  https://upload.wikimedia.org/wikipedia/en/thum...
#
#                                               wiki_link  \
# 1391         https://en.wikipedia.org/wiki/Sheen_(film)
# 1283  https://en.wikipedia.org/wiki/Padmashree_Laloo...
# 1500          https://en.wikipedia.org/wiki/Agni_Varsha
#
#                               title  release_year  runtime  \
# 1391                          Sheen          2004      120
# 1283  Padmashree Laloo Prasad Yadav          2005      120
# 1500                    Agni Varsha          2002      130
#
#                      genres  imdb_rating  imdb_votes  \
# 1391           Action|Drama          6.3          56
# 1283                 Comedy          2.5         168
# 1500  Drama|Fantasy|Romance          4.6         333
#
# ...

# %% [markdown]
# # aggregate functions
#
# - sum()
# - mean()
# - median()
# - mode()
# - min()
# - max()
# - std()
# - var()
# - count()
# - value_counts()
# - groupby()

# %%
# sum
df.runtime.sum()
# Out:
# np.int64(212336)

# %%
plt.figure(figsize=(12,4))
sns.kdeplot(df.runtime)
plt.show()
df.runtime.skew()
# Out:
# np.float64(1.0133660705020242)

# %%
# mean
df.runtime.mean()
# Out:
# np.float64(132.13192283758556)

# %%
# median
df.runtime.median()
# Out:
# 130.0

# %%
# mode
df.runtime.mode()
# Out:
# 0    120
# Name: runtime, dtype: int64

# %%
# var()
df.runtime.var()
# Out:
# 577.9066203975278

# %%
# std
df.runtime.std()
# Out:
# 24.03968844218926

# %%
# count
# categorical

df.genres.count()
# Out:
# np.int64(1607)

# %%
# value_count
# sorting
df.genres.value_counts().sort_values(ascending=False)
# Out:
# genres
# Drama                     157
# Comedy|Drama|Romance      101
# Comedy|Drama               86
# Action|Crime|Drama         86
# Drama|Romance              85
#                          ...
# Musical                     1
# Drama|Fantasy|Thriller      1
# Action|Drama|Fantasy        1
# Family|Fantasy              1
# Comedy|Musical|Mystery      1
# Name: count, Length: 202, dtype: int64

# %%
# groupby

# genres --> ratings

df.groupby('genres')['imdb_rating'].mean().sort_values(ascending=False)
# Out:
# genres
# Documentary|Sport            8.6
# Drama|Fantasy|Horror         8.2
# Adventure|Drama|Musical      8.1
# Comedy|Drama|Short           8.0
# Adventure|Biography|Drama    8.0
#                             ...
# Action|Horror|Sci-Fi         3.1
# Action|Fantasy|Sci-Fi        2.6
# Comedy|Family|Sci-Fi         2.4
# Action|Crime|Romance         2.4
# Biography|History            0.0
# Name: imdb_rating, Length: 202, dtype: float64

# %% [markdown]
# # correlation and statistical
# - corr()
# - cov()
# - kurtosis()

# %%
df.corr(numeric_only=True)
# Out:
#               release_year   runtime  imdb_rating  imdb_votes
# release_year      1.000000 -0.223547     0.124466    0.056970
# runtime          -0.223547  1.000000     0.035503    0.297135
# imdb_rating       0.124466  0.035503     1.000000    0.345997
# imdb_votes        0.056970  0.297135     0.345997    1.000000

# %%
df.cov(numeric_only=True)
# Out:
#               release_year        runtime  imdb_rating    imdb_votes
# release_year     28.860528     -28.870151     1.020780  4.480326e+03
# runtime         -28.870151     577.906620     1.302946  1.045666e+05
# imdb_rating       1.020780       1.302946     2.330563  7.732370e+03
# imdb_votes     4480.325725  104566.570507  7732.370026  2.142990e+08

# %%
# kurtosis

df.runtime
plt.figure(figsize=(12,4))
sns.kdeplot(df.runtime)
plt.show()
df.runtime.skew()

print('kurtosis',df.runtime.kurtosis())
print('leptokurtic situation showcasing std is too low')
# Out:
# kurtosis 6.501936334647867
# leptokurtic situation showcasing std is too low
